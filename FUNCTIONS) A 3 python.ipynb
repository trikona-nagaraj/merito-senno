# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
# * Function helps to reuse the code written for multiple times i.e.. code re-useability is possible when functions are used.
# * Improve the readability and reduce the duplication of code.
# * Reduce chances of errors.
# * Divides a complex problem into simpler ones.

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?
# * when the funtion is called specifying the parameters required then its executed and result can be achieved.

# %% [markdown]
# 3. What statement creates a function?
#
# * The statement which has a def keyword followed by the name of the function and list of arguments (to be taken/considered) in   paranthesis creates a function

# %% [markdown]
# 4. What is the difference between a function and a function call?
# * A funtion is a procedure written to perform a particular task required.
# * A Function Call is using a function already existing in the code to achieve that result in the ongoing statement or step in the code

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?
# * There is one global scope in a python program
#
#
#   Ex: if  a variable is defined outside a function then the value of that variable is constant untill the existing program.

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?
#
# * The local variable retains its value untill the next time function is called. The variable becomes undefined after the function call completes.

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# * a return statement is used inside a function or a method to send the funtion's result back to the caller. A return statement consistes of a return keyword followed by optional return value. the value can be a python object.

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# * If the return statement is without any expression, then the special value None is returned.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?
#
# * By using 'global' keyword followed by variable and value.

# %% [markdown]
# 10. What is the data type of None?
#
# * The None keyword is used to define a Null variable or an object. In python None keyword is an object, and it is a data type of the class None type.

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# * imports the module from which we can access the defined functions or variables in it.

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# * import spam
#
#
#   spam.bacon()
#
#   ---------------
#
#   from spam import bacon()

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# * In try clause all statements are executed untill an exception is encountered.
# * except is used to catch and handle the exceptions that are encountered in a try clause.
