# %% [markdown]
# ## INEURON Python Assignment 1

# %% [markdown]
# 1.     values : The characters assigned to a variable is called the value of that variable.
#
#         ex: a = 'hello' (string)
#         b =  87.8   (float-integer)
#
#         Expression : A mathematical operator is defined as an expression.
#
#         ex: /  division
#             +  addition
#
# 2.      String   : String is one of the data type and is always enclosed in "".
#
#         ex:  "spam"
#
#         variable : The character which can store values in the memory and can assign values
#
#         ex: spam = 23
#
# 3. Data Types:
#
#    Integer  ----- The data type which includes the integer values ex: 1,2,3,4 etc.
#
#    String   ----- This data type identifies characters or letters and written in quotes ex: "data science"
#
#    Float    ----- decimal values of an integer are known to be float values ex: 85.2, 44.0, 4.5.
#
#    bool     ----- True and False   are the keywords with are considered to be bool data type
#
#    complex  ----- The combination of one real value and an imaginary value using an expression are
#
#    called complex numbers in python ex: 2+6j, 4+9j.
#
# 4. what is an expression made up of? what expressions do?
#
#    Expressions are usually mathematical operations.Its usually a mixture of operators and operands .
#
#    ex:a+b-5
#
# 5.  This assignment statements, like spam = 10. What is the difference between an
#
#     expression and a statement?
#
#     Expressions are logical sequence of operators and operands
#
#     while statements are standalone statements which are performed in a single go.

# %% [markdown]
# ## Assigning  and operating  variables

# %%
#6
backon =22
backon+1
# Out:
# 23

# %%
#7
'spam'+'spamspam'
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# 8. Why is eggs a valid variable name while 100 is invalid?
#     eggs is a valid variable name as it doesn’t correspond to any primitive datatype.
#     however 100 is invalid as in python a variable name cannot be a numeric integer

# %% [markdown]
# 9. What three functions can be used to get the integer, floating-point number, or string
# version of a value?
#        -int()    function can be used to get the integer value
#        -float()  function can be used to get the floating point value
#        -string() function can be used to get the string value

# %% [markdown]
# 10. 'I have eaten ' + 99 + ' burritos.'
#
#   This expression causes an error because concatenation is not possible with int and string data type together.
